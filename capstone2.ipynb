# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto: Dataframe Creation

# %% [markdown]
# #### First, I import all the libraries I will need in the assignment

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## 1. Creation of the Toronto dataframe

# %%
# import the library we use to open URLs
import requests

# import the BeautifulSoup library 
# !conda install -c conda-forge beautifulsoup4 --yes
from bs4 import BeautifulSoup
# !pip install lxml


# specify and open the url using urllib.request and put the HTML into the page variable
req = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")

# parse the HTML from our URL 
soup = BeautifulSoup(req.content,'lxml')

table = soup.find_all('table')[0]

df = pd.read_html(str(table))

neighborhood=pd.DataFrame(df[0])
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.9.0       |   py36h9f0ad1d_0         160 KB  conda-forge
#
# The following packages will be UPDATED:
#
#     beautifulsoup4: 4.7.1-py36_1 --> 4.9.0-py36h9f0ad1d_0 conda-forge
#
#
# Downloading and Extracting Packages
# beautifulsoup4-4.9.0 | 160 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Requirement already satisfied: lxml in /opt/conda/envs/Python36/lib/python3.6/site-packages (4.3.1)

# %%
neighborhood.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned                        NaN
# 1         M2A      Not assigned                        NaN
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
neighborhood.tail()
# Out:
#     Postal Code       Borough  \
# 175         M5Z  Not assigned
# 176         M6Z  Not assigned
# 177         M7Z  Not assigned
# 178         M8Z     Etobicoke
# 179         M9Z  Not assigned
#
#                                           Neighborhood
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                                NaN

# %%
#Only process the cells that have an assigned borough

neighborhood=neighborhood[neighborhood.Borough != 'Not assigned']

neighborhood.tail()
# Out:
#     Postal Code           Borough  \
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168              Business reply mail Processing Centre
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...

# %%
# combine more than one neighborhood when they exist in the same  postal code area using COMMA 

neighborhood['Neighborhood'].replace(r' \/ ', ', ', regex=True, inplace=True)

neighborhood.tail()
# Out:
#     Postal Code           Borough  \
# 160         M8X         Etobicoke
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 178         M8Z         Etobicoke
#
#                                           Neighborhood
# 160      The Kingsway, Montgomery Road, Old Mill North
# 165                               Church and Wellesley
# 168              Business reply mail Processing Centre
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 178  Mimico NW, The Queensway West, South of Bloor,...

# %%
#assign borough to neighborhood when neighborhood is Not assigned neighborhood

neighborhood['Neighborhood']=neighborhood['Neighborhood'].replace('Not assigned', neighborhood['Borough'])

# %%
neighborhood.shape
# Out:
# (103, 3)

# %% [markdown]
# ## 2. Get the latitude and the longitude coordinates of each neighborhood

# %%
# !wget -q -O 'toronto_geospatial_data.csv' https://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
torontogeo= pd.read_csv('toronto_geospatial_data.csv')
torontogeo
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# 24          M2R  43.782736 -79.442259
# 25          M3A  43.753259 -79.329656
# 26          M3B  43.745906 -79.352188
# 27          M3C  43.725900 -79.340923
# 28          M3H  43.754328 -79.442259
# 29          M3J  43.767980 -79.487262
# 30          M3K  43.737473 -79.464763
# 31          M3L  43.739015 -79.506944
# 32          M3M  43.728496 -79.495697
# 33          M3N  43.761631 -79.520999
# 34          M4A  43.725882 -79.315572
# 35          M4B  43.706397 -79.309937
# 36          M4C  43.695344 -79.318389
# 37          M4E  43.676357 -79.293031
# 38          M4G  43.709060 -79.363452
# 39          M4H  43.705369 -79.349372
# 40          M4J  43.685347 -79.338106
# 41          M4K  43.679557 -79.352188
# 42          M4L  43.668999 -79.315572
# 43          M4M  43.659526 -79.340923
# 44          M4N  43.728020 -79.388790
# 45          M4P  43.712751 -79.390197
# 46          M4R  43.715383 -79.405678
# 47          M4S  43.704324 -79.388790
# 48          M4T  43.689574 -79.383160
# 49          M4V  43.686412 -79.400049
# 50          M4W  43.679563 -79.377529
# 51          M4X  43.667967 -79.367675
# 52          M4Y  43.665860 -79.383160
# 53          M5A  43.654260 -79.360636
# 54          M5B  43.657162 -79.378937
# 55          M5C  43.651494 -79.375418
# 56          M5E  43.644771 -79.373306
# 57          M5G  43.657952 -79.387383
# 58          M5H  43.650571 -79.384568
# 59          M5J  43.640816 -79.381752
# 60          M5K  43.647177 -79.381576
# 61          M5L  43.648198 -79.379817
# 62          M5M  43.733283 -79.419750
# 63          M5N  43.711695 -79.416936
# 64          M5P  43.696948 -79.411307
# 65          M5R  43.672710 -79.405678
# 66          M5S  43.662696 -79.400049
# 67          M5T  43.653206 -79.400049
# 68          M5V  43.628947 -79.394420
# 69          M5W  43.646435 -79.374846
# 70          M5X  43.648429 -79.382280
# 71          M6A  43.718518 -79.464763
# 72          M6B  43.709577 -79.445073
# 73          M6C  43.693781 -79.428191
# 74          M6E  43.689026 -79.453512
# 75          M6G  43.669542 -79.422564
# 76          M6H  43.669005 -79.442259
# 77          M6J  43.647927 -79.419750
# 78          M6K  43.636847 -79.428191
# 79          M6L  43.713756 -79.490074
# 80          M6M  43.691116 -79.476013
# 81          M6N  43.673185 -79.487262
# 82          M6P  43.661608 -79.464763
# 83          M6R  43.648960 -79.456325
# 84          M6S  43.651571 -79.484450
# 85          M7A  43.662301 -79.389494
# 86          M7R  43.636966 -79.615819
# 87          M7Y  43.662744 -79.321558
# 88          M8V  43.605647 -79.501321
# 89          M8W  43.602414 -79.543484
# 90          M8X  43.653654 -79.506944
# 91          M8Y  43.636258 -79.498509
# 92          M8Z  43.628841 -79.520999
# 93          M9A  43.667856 -79.532242
# 94          M9B  43.650943 -79.554724
# 95          M9C  43.643515 -79.577201
# 96          M9L  43.756303 -79.565963
# 97          M9M  43.724766 -79.532242
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054

# %%
toronto_df = neighborhood.merge(torontogeo)
toronto_df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ## 3. Explore and cluster the Neighborhoods in Etobicoke Borough

# %%
#create a dataframe of Etobicoke borough 

Etobicoke_df = toronto_df[toronto_df['Borough'] == 'Etobicoke'].reset_index(drop=True)
Etobicoke_df
# Out:
#    Postal Code    Borough                                       Neighborhood  \
# 0          M9A  Etobicoke                                   Islington Avenue
# 1          M9B  Etobicoke  West Deane Park, Princess Gardens, Martin Grov...
# 2          M9C  Etobicoke  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 3          M9P  Etobicoke                                          Westmount
# 4          M9R  Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
# 5          M8V  Etobicoke       New Toronto, Mimico South, Humber Bay Shores
# 6          M9V  Etobicoke  South Steeles, Silverstone, Humbergate, Jamest...
# 7          M8W  Etobicoke                             Alderwood, Long Branch
# 8          M9W  Etobicoke                                          Northwest
# 9          M8X  Etobicoke      The Kingsway, Montgomery Road, Old Mill North
# 10         M8Y  Etobicoke  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 11         M8Z  Etobicoke  Mimico NW, The Queensway West, South of Bloor,...
#
#      Latitude  Longitude
# 0   43.667856 -79.532242
# 1   43.650943 -79.554724
# 2   43.643515 -79.577201
# 3   43.696319 -79.532242
# 4   43.688905 -79.554724
# 5   43.605647 -79.501321
# 6   43.739416 -79.588437
# 7   43.602414 -79.543484
# 8   43.706748 -79.594054
# 9   43.653654 -79.506944
# 10  43.636258 -79.498509
# 11  43.628841 -79.520999

# %%
#geographical coordinates for Etobicoke

address = 'Etobicoke, TO'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Etobicoke are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Etobicoke are 43.671459150000004, -79.55249206611668.

# %%
# create map of Etobicoke using latitude and longitude values
map_Etobicoke = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(Etobicoke_df['Latitude'], Etobicoke_df['Longitude'], Etobicoke_df['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Etobicoke)  
    
map_Etobicoke
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#define Foursquare details 


CLIENT_ID = 'IB43C4M5C1VPP0XRNG2SSB2R1VQUWVYWODFN1114FWQVLR5Q' 
CLIENT_SECRET = 'N3NWM2XUOXRZDJOPYAY13XA5REUKXSRDEX1TCF23GD5VQJ0O' 
VERSION = '20180605' 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IB43C4M5C1VPP0XRNG2SSB2R1VQUWVYWODFN1114FWQVLR5Q
# CLIENT_SECRET:N3NWM2XUOXRZDJOPYAY13XA5REUKXSRDEX1TCF23GD5VQJ0O

# %%
#Function to explore the neighborhoods venues

LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius


def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#create a dataframe with all Etobicoke venues by calling the function getNearbyVenues

Etobicoke_venues = getNearbyVenues(names=Etobicoke_df['Neighborhood'],latitudes=Etobicoke_df['Latitude'], longitudes=Etobicoke_df['Longitude'])

print(Etobicoke_venues.shape)
Etobicoke_venues.head()
# Out:
# Islington Avenue
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Westmount
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Alderwood, Long Branch
# Northwest
# The Kingsway, Montgomery Road, Old Mill North
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# (75, 7)
#                                         Neighborhood  Neighborhood Latitude  \
# 0  West Deane Park, Princess Gardens, Martin Grov...              43.650943
# 1  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.643515
# 2  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.643515
# 3  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.643515
# 4  Eringate, Bloordale Gardens, Old Burnhamthorpe...              43.643515
#
#    Neighborhood Longitude               Venue  Venue Latitude  \
# 0              -79.554724  Seaforth Golf Club       43.651183
# 1              -79.577201                LCBO       43.642099
# 2              -79.577201           Starbucks       43.641312
# 3              -79.577201      The Beer Store       43.641313
# 4              -79.577201  Shoppers Drug Mart       43.641312
#
#    Venue Longitude  Venue Category
# 0       -79.556107     Golf Course
# 1       -79.576592    Liquor Store
# 2       -79.576924     Coffee Shop
# 3       -79.576925      Beer Store
# 4       -79.576924  Cosmetics Shop

# %%
# check the venues returned for each neighborhood 

Etobicoke_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Alderwood, Long Branch                                                 10
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...                      7
# Kingsview Village, St. Phillips, Martin Grove G...                      4
# Mimico NW, The Queensway West, South of Bloor, ...                     13
# New Toronto, Mimico South, Humber Bay Shores                           15
# Northwest                                                               2
# Old Mill South, King's Mill Park, Sunnylea, Hum...                      3
# South Steeles, Silverstone, Humbergate, Jamesto...                     11
# The Kingsway, Montgomery Road, Old Mill North                           2
# West Deane Park, Princess Gardens, Martin Grove...                      1
# Westmount                                                               7
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Alderwood, Long Branch                                                  10
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...                       7
# Kingsview Village, St. Phillips, Martin Grove G...                       4
# Mimico NW, The Queensway West, South of Bloor, ...                      13
# New Toronto, Mimico South, Humber Bay Shores                            15
# Northwest                                                                2
# Old Mill South, King's Mill Park, Sunnylea, Hum...                       3
# South Steeles, Silverstone, Humbergate, Jamesto...                      11
# The Kingsway, Montgomery Road, Old Mill North                            2
# West Deane Park, Princess Gardens, Martin Grove...                       1
# Westmount                                                                7
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Alderwood, Long Branch                                 10              10
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...      7               7
# Kingsview Village, St. Phillips, Martin Grove G...      4               4
# Mimico NW, The Queensway West, South of Bloor, ...     13              13
# New Toronto, Mimico South, Humber Bay Shores           15              15
# Northwest                                               2               2
# Old Mill South, King's Mill Park, Sunnylea, Hum...      3               3
# South Steeles, Silverstone, Humbergate, Jamesto...     11              11
# The Kingsway, Montgomery Road, Old Mill North           2               2
# West Deane Park, Princess Gardens, Martin Grove...      1               1
# Westmount                                               7               7
#
#                                                     Venue Longitude  \
# Neighborhood
# Alderwood, Long Branch                                           10
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...                7
# Kingsview Village, St. Phillips, Martin Grove G...                4
# Mimico NW, The Queensway West, South of Bloor, ...               13
# New Toronto, Mimico South, Humber Bay Shores                     15
# Northwest                                                         2
# Old Mill South, King's Mill Park, Sunnylea, Hum...                3
# South Steeles, Silverstone, Humbergate, Jamesto...               11
# The Kingsway, Montgomery Road, Old Mill North                     2
# West Deane Park, Princess Gardens, Martin Grove...                1
# Westmount                                                         7
#
#                                                     Venue Category
# Neighborhood
# Alderwood, Long Branch                                          10
# Eringate, Bloordale Gardens, Old Burnhamthorpe,...               7
# Kingsview Village, St. Phillips, Martin Grove G...               4
# Mimico NW, The Queensway West, South of Bloor, ...              13
# New Toronto, Mimico South, Humber Bay Shores                    15
# Northwest                                                        2
# Old Mill South, King's Mill Park, Sunnylea, Hum...               3
# South Steeles, Silverstone, Humbergate, Jamesto...              11
# The Kingsway, Montgomery Road, Old Mill North                    2
# West Deane Park, Princess Gardens, Martin Grove...               1
# Westmount                                                        7

# %% [markdown]
# #### Analyze each neighborhood

# %%
# one hot encoding
Etobicoke_onehot = pd.get_dummies(Etobicoke_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Etobicoke_onehot['Neighborhood'] = Etobicoke_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [Etobicoke_onehot.columns[-1]] + list(Etobicoke_onehot.columns[:-1])
Etobicoke_onehot = Etobicoke_onehot[fixed_columns]

Etobicoke_onehot.head()
Etobicoke_onehot.shape
# Out:
# (75, 45)

# %%
#group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

Etobicoke_grouped = Etobicoke_onehot.groupby('Neighborhood').mean().reset_index()
Etobicoke_grouped
Etobicoke_grouped.shape
# Out:
# (11, 45)

# %%
#5 most common venues for each neighborhood 

num_top_venues = 5

for hood in Etobicoke_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Etobicoke_grouped[Etobicoke_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Alderwood, Long Branch----
#             venue  freq
# 0     Pizza Place   0.2
# 1             Gym   0.1
# 2    Dance Studio   0.1
# 3    Skating Rink   0.1
# 4  Sandwich Place   0.1
#
#
# ----Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood----
#             venue  freq
# 0    Liquor Store  0.14
# 1      Beer Store  0.14
# 2  Shopping Plaza  0.14
# 3            Café  0.14
# 4     Coffee Shop  0.14
#
#
# ----Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens----
#                  venue  freq
# 0    Mobile Phone Shop  0.25
# 1             Bus Line  0.25
# 2       Sandwich Place  0.25
# 3          Pizza Place  0.25
# 4  American Restaurant  0.00
#
#
# ----Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West----
#                venue  freq
# 0                Gym  0.08
# 1  Convenience Store  0.08
# 2    Supplement Shop  0.08
# 3     Sandwich Place  0.08
# 4     Hardware Store  0.08
#
#
# ----New Toronto, Mimico South, Humber Bay Shores----
#                   venue  freq
# 0                  Café  0.13
# 1   American Restaurant  0.07
# 2  Fast Food Restaurant  0.07
# 3    Seafood Restaurant  0.07
# 4            Restaurant  0.07
#
#
# ----Northwest----
#                  venue  freq
# 0            Drugstore   0.5
# 1  Rental Car Location   0.5
# 2  American Restaurant   0.0
# 3                 Pool   0.0
# 4         Liquor Store   0.0
#
#
# ----Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East----
#                         venue  freq
# 0  Construction & Landscaping  0.33
# 1              Baseball Field  0.33
# 2              Breakfast Spot  0.33
# 3         Rental Car Location  0.00
# 4          Mexican Restaurant  0.00
#
#
# ----South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens----
#                  venue  freq
# 0        Grocery Store  0.18
# 1          Pizza Place  0.09
# 2          Video Store  0.09
# 3           Beer Store  0.09
# 4  Fried Chicken Joint  0.09
#
#
# ----The Kingsway, Montgomery Road, Old Mill North----
#                  venue  freq
# 0                 Park   0.5
# 1                River   0.5
# 2  American Restaurant   0.0
# 3                 Pool   0.0
# 4         Intersection   0.0
#
#
# ----West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale----
#                  venue  freq
# 0          Golf Course   1.0
# 1  American Restaurant   0.0
# 2       Hardware Store   0.0
# 3         Liquor Store   0.0
# 4   Mexican Restaurant   0.0
#
#
# ----Westmount----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.14
# 1             Sandwich Place  0.14
# 2                Pizza Place  0.14
# 3         Chinese Restaurant  0.14
# 4                Coffee Shop  0.14

# %%
#function to sort vanues in descending order 

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
#new dataframe that displays the top 10 venues for each neighborhood

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Etobicoke_grouped['Neighborhood']

for ind in np.arange(Etobicoke_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Etobicoke_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                             Alderwood, Long Branch           Pizza Place
# 1  Eringate, Bloordale Gardens, Old Burnhamthorpe...        Shopping Plaza
# 2  Kingsview Village, St. Phillips, Martin Grove ...        Sandwich Place
# 3  Mimico NW, The Queensway West, South of Bloor,...           Wings Joint
# 4       New Toronto, Mimico South, Humber Bay Shores                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Skating Rink          Dance Studio                   Gym
# 1            Beer Store          Liquor Store        Cosmetics Shop
# 2              Bus Line     Mobile Phone Shop           Pizza Place
# 3        Hardware Store                Bakery          Burger Joint
# 4   American Restaurant           Flower Shop   Fried Chicken Joint
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Sandwich Place                   Pub                  Pool
# 1                  Café           Pizza Place           Coffee Shop
# 2           Wings Joint           Coffee Shop  Fast Food Restaurant
# 3         Burrito Place     Convenience Store        Discount Store
# 4                   Gym          Liquor Store    Mexican Restaurant
#
#   8th Most Common Venue       9th Most Common Venue 10th Most Common Venue
# 0           Coffee Shop                    Pharmacy                   Café
# 1           Wings Joint  Construction & Landscaping   Fast Food Restaurant
# 2             Drugstore              Discount Store           Dance Studio
# 3  Fast Food Restaurant                 Flower Shop                    Gym
# 4           Coffee Shop                 Pizza Place               Pharmacy

# %% [markdown]
# ### Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

Etobicoke_grouped_clustering = Etobicoke_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Etobicoke_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 2, 2, 2, 2, 0, 3, 2, 4, 1], dtype=int32)

# %%
#new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Etobicoke_merged = Etobicoke_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
Etobicoke_merged = Etobicoke_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Etobicoke_merged.head() # check the last columns!
# Out:
#   Postal Code    Borough                                       Neighborhood  \
# 0         M9A  Etobicoke                                   Islington Avenue
# 1         M9B  Etobicoke  West Deane Park, Princess Gardens, Martin Grov...
# 2         M9C  Etobicoke  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 3         M9P  Etobicoke                                          Westmount
# 4         M9R  Etobicoke  Kingsview Village, St. Phillips, Martin Grove ...
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.667856 -79.532242             NaN                   NaN
# 1  43.650943 -79.554724             1.0           Golf Course
# 2  43.643515 -79.577201             2.0        Shopping Plaza
# 3  43.696319 -79.532242             2.0           Pizza Place
# 4  43.688905 -79.554724             2.0        Sandwich Place
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   NaN                   NaN                   NaN
# 1           Video Store   Fried Chicken Joint           Flower Shop
# 2            Beer Store          Liquor Store        Cosmetics Shop
# 3           Coffee Shop        Discount Store          Intersection
# 4              Bus Line     Mobile Phone Shop           Pizza Place
#
#   5th Most Common Venue      6th Most Common Venue 7th Most Common Venue  \
# 0                   NaN                        NaN                   NaN
# 1  Fast Food Restaurant                  Drugstore        Discount Store
# 2                  Café                Pizza Place           Coffee Shop
# 3        Sandwich Place  Middle Eastern Restaurant    Chinese Restaurant
# 4           Wings Joint                Coffee Shop  Fast Food Restaurant
#
#   8th Most Common Venue       9th Most Common Venue 10th Most Common Venue
# 0                   NaN                         NaN                    NaN
# 1          Dance Studio              Cosmetics Shop      Convenience Store
# 2           Wings Joint  Construction & Landscaping   Fast Food Restaurant
# 3  Fast Food Restaurant                   Drugstore           Dance Studio
# 4             Drugstore              Discount Store           Dance Studio

# %%
#map the clusters 

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Etobicoke_merged['Latitude'], Etobicoke_merged['Longitude'], Etobicoke_merged['Neighborhood'], Etobicoke_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='#3186cc',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %%
#Cluster 1 

Etobicoke_merged.loc[Etobicoke_merged['Cluster Labels'] == 0, Etobicoke_merged.columns[[1] + list(range(5, Etobicoke_merged.shape[1]))]]
# Out:
#      Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 8  Etobicoke             0.0             Drugstore   Rental Car Location
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 8           Wings Joint           Coffee Shop           Flower Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 8  Fast Food Restaurant        Discount Store          Dance Studio
#
#   9th Most Common Venue 10th Most Common Venue
# 8        Cosmetics Shop      Convenience Store

# %%
#Cluster 2

Etobicoke_merged.loc[Etobicoke_merged['Cluster Labels'] == 1, Etobicoke_merged.columns[[1] + list(range(5, Etobicoke_merged.shape[1]))]]
# Out:
#      Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1  Etobicoke             1.0           Golf Course           Video Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1   Fried Chicken Joint           Flower Shop  Fast Food Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1             Drugstore        Discount Store          Dance Studio
#
#   9th Most Common Venue 10th Most Common Venue
# 1        Cosmetics Shop      Convenience Store

# %%
#Cluster 3 

Etobicoke_merged.loc[Etobicoke_merged['Cluster Labels'] == 2, Etobicoke_merged.columns[[1] + list(range(5, Etobicoke_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2   Etobicoke             2.0        Shopping Plaza            Beer Store
# 3   Etobicoke             2.0           Pizza Place           Coffee Shop
# 4   Etobicoke             2.0        Sandwich Place              Bus Line
# 5   Etobicoke             2.0                  Café   American Restaurant
# 6   Etobicoke             2.0         Grocery Store              Pharmacy
# 7   Etobicoke             2.0           Pizza Place          Skating Rink
# 11  Etobicoke             2.0           Wings Joint        Hardware Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2           Liquor Store        Cosmetics Shop                  Café
# 3         Discount Store          Intersection        Sandwich Place
# 4      Mobile Phone Shop           Pizza Place           Wings Joint
# 5            Flower Shop   Fried Chicken Joint                   Gym
# 6   Fast Food Restaurant           Video Store          Liquor Store
# 7           Dance Studio                   Gym        Sandwich Place
# 11                Bakery          Burger Joint         Burrito Place
#
#         6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2                 Pizza Place           Coffee Shop           Wings Joint
# 3   Middle Eastern Restaurant    Chinese Restaurant  Fast Food Restaurant
# 4                 Coffee Shop  Fast Food Restaurant             Drugstore
# 5                Liquor Store    Mexican Restaurant           Coffee Shop
# 6                 Coffee Shop           Pizza Place   Fried Chicken Joint
# 7                         Pub                  Pool           Coffee Shop
# 11          Convenience Store        Discount Store  Fast Food Restaurant
#
#          9th Most Common Venue 10th Most Common Venue
# 2   Construction & Landscaping   Fast Food Restaurant
# 3                    Drugstore           Dance Studio
# 4               Discount Store           Dance Studio
# 5                  Pizza Place               Pharmacy
# 6               Sandwich Place             Beer Store
# 7                     Pharmacy                   Café
# 11                 Flower Shop                    Gym

# %%
#Cluster 4

Etobicoke_merged.loc[Etobicoke_merged['Cluster Labels'] == 3, Etobicoke_merged.columns[[1] + list(range(5, Etobicoke_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels       1st Most Common Venue  \
# 10  Etobicoke             3.0  Construction & Landscaping
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 10        Baseball Field        Breakfast Spot           Wings Joint
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 10   Fried Chicken Joint           Flower Shop  Fast Food Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 10             Drugstore        Discount Store           Dance Studio

# %%
#Cluster 5

Etobicoke_merged.loc[Etobicoke_merged['Cluster Labels'] == 4, Etobicoke_merged.columns[[1] + list(range(5, Etobicoke_merged.shape[1]))]]
# Out:
#      Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 9  Etobicoke             4.0                 River                  Park
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 9           Wings Joint           Coffee Shop           Flower Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 9  Fast Food Restaurant             Drugstore        Discount Store
#
#   9th Most Common Venue 10th Most Common Venue
# 9          Dance Studio         Cosmetics Shop

# %% [markdown]
# ## The End
